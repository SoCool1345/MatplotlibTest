# %% [markdown]
# # Homework 1 for CS 329P
#
# **Authors**: YOUR_NAMES
#
# **Emails**: YOUR_IDS@stanford.edu
#
# **Submission.** Please insert your names and emails above, save your code in this notebook, and explain what you are doing along with your findings in text cells. You can think of it as a technical report with code. Before submission, please use `Kernel -> Restart & Run All` in the Jupyter menu to verify your code is runnable and save all outputs. Afterwards, you can either upload your raw notebook (`hw1.ipynb`) or an exported PDF version to the `Homework 1` assignment in Canvas.
#
#
# In this homework, we will train a house sales price predictor on the data we scraped previously. The purpose of this homework is to let you practice different techniques that you can use to preprocess raw data. Your job is to obtain the best root mean squared logarithmic error (RMSLE) on the test dataset. To make your job easy, we provide sample code to train a model to report RMSLE and a list of ideas you can explore.
#
# **Note**: You can use either local runtimes to complete this assignment, or a hosted runtime (with GPU) on Colab. The second option generally runs faster. If using a local runtime, make sure that your Python version is less than 3.9 but at least 3.6, or you may have issues installing Autogluon. If using a runtime hosted on Colab, you can use the File Explorer pane on the left to upload the `house_sales.ftr` file. Make sure to wait until the file finishes uploading before running the next code block.
#
# Additionally, if using a local runtime, please refer to the [AG document](https://auto.gluon.ai/stable/index.html#installation) for info on how to install autogluon.
#
# ## Prepare Data
#
# Let's first read in the dataset we used in our [Exploratory Data Analysis (EDA)](https://c.d2l.ai/stanford-cs329p/_static/notebooks/cs329p_notebook_eda.slides.html). Note that we use the [`feather` format](https://arrow.apache.org/docs/python/feather.html), which is faster to read than CSV but uses more disk space. The file `home_sales.ftr` can be downloaded from the Assignments folder in Canvas.
#
# Just for your information, it is generated with:
#
# ```python
# data = pd.read_csv('house_sales.zip', dtype='unicode')
# data.to_feather('house_sales.ftr')
# ```
#
# The following code needs at least 2GB memory. If using a local runtime, please make sure your machine has enough memory.

# %%
# Run the following line once to install. You may need to restart your runtime afterwards:
# !pip3 install numpy pandas autogluon mxnet --upgrade
import pandas as pd
import numpy as np

data = pd.read_feather('house_sales.ftr')
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-qqlrp8r5\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (101 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Downloading setuptools-60.9.0-py3-none-any.whl (1.1 MB)
#   Collecting wheel
#     Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.17.3
#     Downloading numpy-1.17.3.zip (6.4 MB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
#   Using legacy 'setup.py install' for numpy, since package 'wheel' is not installed.
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-bk6ruyck\\numpy_1e739f49a08044c3a282dd8d3122d034\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-bk6ruyck\\numpy_1e739f49a08044c3a282dd8d3122d034\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-tsb04nog\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay\include\site\python3.9\numpy'
#            cwd: C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\
#       Complete output (71 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       Could not locate executable g77
#       Could not locate executable f77
#       Could not locate executable ifort
#       Could not locate executable ifl
#       Could not locate executable f90
#       Could not locate executable DF
#       Could not locate executable efl
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable g95
#       Could not locate executable efort
#       Could not locate executable efc
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#       'svnversion' 不是内部或外部命令，也不是可运行的程序
#       或批处理文件。
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-bk6ruyck\numpy_1e739f49a08044c3a282dd8d3122d034\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       d:\pythonproject\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       running install
#       d:\pythonproject\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       running config_fc
#       running build_src
#       creating build
#       creating build\src.win-amd64-3.9
#       creating build\src.win-amd64-3.9\numpy
#       creating build\src.win-amd64-3.9\numpy\distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-bk6ruyck\\numpy_1e739f49a08044c3a282dd8d3122d034\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-bk6ruyck\\numpy_1e739f49a08044c3a282dd8d3122d034\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-tsb04nog\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay\include\site\python3.9\numpy' Check the logs for full command output.
#   WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
#   You should consider upgrading via the 'd:\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-qqlrp8r5\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-vfyvem2r\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-hwkl9obm\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (101 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-60.9.0-py3-none-any.whl (1.1 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
#   Using legacy 'setup.py install' for numpy, since package 'wheel' is not installed.
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-htd8fc03\\numpy_6e92c16120084cf889e778c8019a0f05\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-htd8fc03\\numpy_6e92c16120084cf889e778c8019a0f05\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-671rke57\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay\include\site\python3.9\numpy'
#            cwd: C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\
#       Complete output (71 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       Could not locate executable g77
#       Could not locate executable f77
#       Could not locate executable ifort
#       Could not locate executable ifl
#       Could not locate executable f90
#       Could not locate executable DF
#       Could not locate executable efl
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable g95
#       Could not locate executable efort
#       Could not locate executable efc
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#       'svnversion' 不是内部或外部命令，也不是可运行的程序
#       或批处理文件。
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-htd8fc03\numpy_6e92c16120084cf889e778c8019a0f05\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       d:\pythonproject\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       running install
#       d:\pythonproject\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       running config_fc
#       running build_src
#       creating build
#       creating build\src.win-amd64-3.9
#       creating build\src.win-amd64-3.9\numpy
#       creating build\src.win-amd64-3.9\numpy\distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-htd8fc03\\numpy_6e92c16120084cf889e778c8019a0f05\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-htd8fc03\\numpy_6e92c16120084cf889e778c8019a0f05\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-671rke57\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay\include\site\python3.9\numpy' Check the logs for full command output.
#   WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
#   You should consider upgrading via the 'd:\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/23/b0/ff0f4ffa3da1ddb242a295d5d19dd1775f567ad73a6ea7474eaa55e04836/scikit-learn-0.23.1.tar.gz#sha256=e3fec1c8831f8f93ad85581ca29ca1bb88e2da377fb097cf8322aa89c21bc9b8 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-hwkl9obm\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-xk0tw48s\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-287o145d\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (100 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-60.9.0-py3-none-any.whl (1.1 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
#   Using legacy 'setup.py install' for numpy, since package 'wheel' is not installed.
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_287dgvc\\numpy_7188f1ea52574e19b3f3e2a7522d07ee\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_287dgvc\\numpy_7188f1ea52574e19b3f3e2a7522d07ee\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-ct2zut5l\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay\include\site\python3.9\numpy'
#            cwd: C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\
#       Complete output (71 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       Could not locate executable g77
#       Could not locate executable f77
#       Could not locate executable ifort
#       Could not locate executable ifl
#       Could not locate executable f90
#       Could not locate executable DF
#       Could not locate executable efl
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable g95
#       Could not locate executable efort
#       Could not locate executable efc
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#       'svnversion' 不是内部或外部命令，也不是可运行的程序
#       或批处理文件。
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_287dgvc\numpy_7188f1ea52574e19b3f3e2a7522d07ee\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       d:\pythonproject\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       running install
#       d:\pythonproject\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       running config_fc
#       running build_src
#       creating build
#       creating build\src.win-amd64-3.9
#       creating build\src.win-amd64-3.9\numpy
#       creating build\src.win-amd64-3.9\numpy\distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_287dgvc\\numpy_7188f1ea52574e19b3f3e2a7522d07ee\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_287dgvc\\numpy_7188f1ea52574e19b3f3e2a7522d07ee\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-ct2zut5l\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay\include\site\python3.9\numpy' Check the logs for full command output.
#   WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
#   You should consider upgrading via the 'd:\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/72/e4/75247cf75e9e3ba1bf296c9d26ba1cfc71d781821d32bcdb4d9b4b1b4153/scikit-learn-0.23.0.tar.gz#sha256=639a53df6273acc6a7510fb0c658b94e0c70bb13dafff9d14932c981ff9baff4 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-287o145d\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-nsm7c3oh\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-k3unp57v\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- 'cython >= 0.29' 'numpy==1.14.5; python_version<'"'"'3.7'"'"'' 'numpy==1.16.0; python_version>='"'"'3.7'"'"'' setuptools setuptools_scm wheel
#        cwd: None
#   Complete output (104 lines):
#   Ignoring numpy: markers 'python_version < "3.7"' don't match your environment
#   Collecting cython>=0.29
#     Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.16.0
#     Downloading numpy-1.16.0.zip (5.1 MB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting setuptools
#     Using cached setuptools-60.9.0-py3-none-any.whl (1.1 MB)
#   Collecting setuptools_scm
#     Downloading setuptools_scm-6.4.2-py3-none-any.whl (37 kB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting packaging>=20.0
#     Using cached packaging-21.3-py3-none-any.whl (40 kB)
#   Collecting tomli>=1.0.0
#     Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
#   Collecting pyparsing!=3.0.5,>=2.0.2
#     Using cached pyparsing-3.0.7-py3-none-any.whl (98 kB)
#   Using legacy 'setup.py install' for numpy, since package 'wheel' is not installed.
#   Installing collected packages: pyparsing, tomli, setuptools, packaging, wheel, setuptools-scm, numpy, cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_om1umu2\\numpy_8a2adc4c8a564391be0aff9bda4e69bd\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_om1umu2\\numpy_8a2adc4c8a564391be0aff9bda4e69bd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-jltd1dn1\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay\include\site\python3.9\numpy'
#            cwd: C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\
#       Complete output (73 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#         return is_string(s) and ('*' in s or '?' is s)
#       Could not locate executable g77
#       Could not locate executable f77
#       Could not locate executable ifort
#       Could not locate executable ifl
#       Could not locate executable f90
#       Could not locate executable DF
#       Could not locate executable efl
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable g95
#       Could not locate executable efort
#       Could not locate executable efc
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\system_info.py:625: UserWarning:
#           Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [atlas]) or by setting
#           the ATLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\system_info.py:625: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\system_info.py:625: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#       'svnversion' 不是内部或外部命令，也不是可运行的程序
#       或批处理文件。
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\system_info.py:625: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-_om1umu2\numpy_8a2adc4c8a564391be0aff9bda4e69bd\numpy\distutils\system_info.py:625: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         self.calc_info()
#       d:\pythonproject\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       running install
#       d:\pythonproject\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       running config_fc
#       running build_src
#       creating build
#       creating build\src.win-amd64-3.9
#       creating build\src.win-amd64-3.9\numpy
#       creating build\src.win-amd64-3.9\numpy\distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_om1umu2\\numpy_8a2adc4c8a564391be0aff9bda4e69bd\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-_om1umu2\\numpy_8a2adc4c8a564391be0aff9bda4e69bd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-jltd1dn1\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay\include\site\python3.9\numpy' Check the logs for full command output.
#   WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
#   You should consider upgrading via the 'd:\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f2/c6/93744c9b5243fa8a129b44e39b34b9bd4261ed42fe93c9dfb6ddd99f8af8/pyarrow-1.0.0.tar.gz#sha256=5ae4da65ba94d27cd1f1d583186de42511061f430f09bd112843c03ac3bcf9d0 (from https://pypi.org/simple/pyarrow/) (requires-python:>=3.5). Command errored out with exit status 1: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-k3unp57v\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-rcz3z84y\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- 'cython >= 0.29' 'numpy==1.14.5; python_version<'"'"'3.7'"'"'' 'numpy==1.16.0; python_version>='"'"'3.7'"'"'' setuptools setuptools_scm wheel Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\pythonproject\scripts\python.exe' 'C:\Users\Administrator\AppData\Local\Temp\pip-standalone-pip-j_20hvjn\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-noumqikz\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- 'cython >= 0.29' 'numpy==1.14.5; python_version<'"'"'3.7'"'"'' 'numpy==1.16.0; python_version>='"'"'3.7'"'"'' setuptools setuptools_scm wheel
#        cwd: None
#   Complete output (104 lines):
#   Ignoring numpy: markers 'python_version < "3.7"' don't match your environment
#   Collecting cython>=0.29
#     Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
#   Collecting numpy==1.16.0
#     Using cached numpy-1.16.0.zip (5.1 MB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting setuptools
#     Using cached setuptools-60.9.0-py3-none-any.whl (1.1 MB)
#   Collecting setuptools_scm
#     Using cached setuptools_scm-6.4.2-py3-none-any.whl (37 kB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting packaging>=20.0
#     Using cached packaging-21.3-py3-none-any.whl (40 kB)
#   Collecting tomli>=1.0.0
#     Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
#   Collecting pyparsing!=3.0.5,>=2.0.2
#     Using cached pyparsing-3.0.7-py3-none-any.whl (98 kB)
#   Using legacy 'setup.py install' for numpy, since package 'wheel' is not installed.
#   Installing collected packages: pyparsing, tomli, setuptools, packaging, wheel, setuptools-scm, numpy, cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'd:\pythonproject\scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-y6on4grq\\numpy_0e14a9e6d4294252875ff1fc89ee9f89\\setup.py'"'"'; __file__='"'"'C:\\Users\\Administrator\\AppData\\Local\\Temp\\pip-install-y6on4grq\\numpy_0e14a9e6d4294252875ff1fc89ee9f89\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Administrator\AppData\Local\Temp\pip-record-9bhq3915\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-noumqikz\overlay' --compile --install-headers 'C:\Users\Administrator\AppData\Local\Temp\pip-build-env-noumqikz\overlay\include\site\python3.9\numpy'
#            cwd: C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\
#       Complete output (73 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#         return is_string(s) and ('*' in s or '?' is s)
#       Could not locate executable g77
#       Could not locate executable f77
#       Could not locate executable ifort
#       Could not locate executable ifl
#       Could not locate executable f90
#       Could not locate executable DF
#       Could not locate executable efl
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable g95
#       Could not locate executable efort
#       Could not locate executable efc
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\system_info.py:625: UserWarning:
#           Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [atlas]) or by setting
#           the ATLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\system_info.py:625: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\system_info.py:625: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#       'svnversion' 不是内部或外部命令，也不是可运行的程序
#       或批处理文件。
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\system_info.py:625: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         self.calc_info()
#       C:\Users\Administrator\AppData\Local\Temp\pip-install-y6on4grq\numpy_0e14a9e6d4294252875ff1fc89ee9f89\numpy\distutils\system_info.py:625: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         self.calc_info()
#       d:\pythonproject\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       non-existing path in 'numpy\\distutils': 'site.cfg'
# ...
# Requirement already satisfied: numpy in d:\pythonproject\lib\site-packages (1.22.1)
# Collecting numpy
#   Downloading numpy-1.22.2-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: pandas in d:\pythonproject\lib\site-packages (1.4.0)
# Collecting pandas
#   Downloading pandas-1.4.1-cp39-cp39-win_amd64.whl (10.5 MB)
# Collecting autogluon
#   Downloading autogluon-0.0.15-py3-none-any.whl (622 kB)
# Collecting mxnet
#   Downloading mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\pythonproject\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\pythonproject\lib\site-packages (from pandas) (2021.3)
# Collecting pytest
#   Downloading pytest-7.0.1-py3-none-any.whl (296 kB)
# Collecting dask>=2.6.0
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
# Collecting fastparquet==0.4.1
#   Downloading fastparquet-0.4.1.tar.gz (28.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy>=1.3.3 in d:\pythonproject\lib\site-packages (from autogluon) (1.8.0)
# Collecting networkx<3.0,>=2.3
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting Pillow<=6.2.1
#   Downloading Pillow-6.2.1.tar.gz (37.7 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ConfigSpace<=0.4.10
#   Downloading ConfigSpace-0.4.10.tar.gz (882 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cryptography>=2.8
#   Downloading cryptography-36.0.1-cp36-abi3-win_amd64.whl (2.2 MB)
# Collecting tqdm>=4.38.0
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting gluoncv<0.9.0,>=0.5.0
#   Downloading gluoncv-0.8.0-py2.py3-none-any.whl (810 kB)
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Collecting catboost<0.25,>=0.23.0
#   Downloading catboost-0.24.4-cp39-none-win_amd64.whl (65.4 MB)
# Collecting scikit-learn<0.24,>=0.22.0
#   Downloading scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading scikit-learn-0.23.1.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading scikit-learn-0.23.0.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading scikit-learn-0.22.2.post1.tar.gz (6.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: tornado>=5.0.1 in d:\pythonproject\lib\site-packages (from autogluon) (6.1)
# Collecting psutil<=5.7.0,>=5.0.0
#   Downloading psutil-5.7.0.tar.gz (449 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting paramiko>=2.4
#   Downloading paramiko-2.9.2-py2.py3-none-any.whl (210 kB)
# Requirement already satisfied: matplotlib in d:\pythonproject\lib\site-packages (from autogluon) (3.5.1)
# Collecting boto3
#   Downloading boto3-1.21.0-py3-none-any.whl (132 kB)
# Collecting autogluon-contrib-nlp
#   Downloading autogluon_contrib_nlp-0.0.1b20220208-py3-none-any.whl (157 kB)
# Collecting cython
#   Using cached Cython-0.29.27-py2.py3-none-any.whl (983 kB)
# Collecting distributed>=2.6.0
#   Downloading distributed-2022.2.0-py3-none-any.whl (837 kB)
# Collecting openml
#   Downloading openml-0.12.2.tar.gz (119 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyarrow<=1.0.0
#   Downloading pyarrow-1.0.0.tar.gz (1.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading pyarrow-0.17.1.tar.gz (2.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading pyarrow-0.17.0.tar.gz (3.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading pyarrow-0.16.0.tar.gz (5.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Downloading pyarrow-0.15.1.tar.gz (5.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in d:\pythonproject\lib\site-packages (from autogluon) (2.27.1)
# Collecting numba>=0.28
#   Downloading numba-0.55.1-cp39-cp39-win_amd64.whl (2.4 MB)
# Requirement already satisfied: packaging in d:\pythonproject\lib\site-packages (from fastparquet==0.4.1->autogluon) (21.3)
# Collecting thrift>=0.11.0
#   Downloading thrift-0.15.0.tar.gz (59 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in d:\pythonproject\lib\site-packages (from fastparquet==0.4.1->autogluon) (1.16.0)
# Collecting requests
#   Downloading requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting mxnet
#   Downloading mxnet-1.7.0.post1-py2.py3-none-win_amd64.whl (33.0 MB)
#   Downloading mxnet-1.6.0-py2.py3-none-win_amd64.whl (26.9 MB)
#   Downloading mxnet-1.5.0-py2.py3-none-win_amd64.whl (23.5 MB)
#   Downloading mxnet-1.4.1-py2.py3-none-win_amd64.whl (21.9 MB)
#   Downloading mxnet-1.4.0.post0-py2.py3-none-win_amd64.whl (21.9 MB)
#   Downloading mxnet-1.4.0-py2.py3-none-win_amd64.whl (21.9 MB)
#   Downloading mxnet-1.3.1-py2.py3-none-win_amd64.whl (21.5 MB)
#   Downloading mxnet-1.3.0-1-py2.py3-none-win_amd64.whl (21.5 MB)
#   Downloading mxnet-1.2.1.post1-py2.py3-none-win_amd64.whl (20.0 MB)
#   Downloading mxnet-1.2.1-py2.py3-none-win_amd64.whl (20.0 MB)
#   Downloading mxnet-1.2.0-py2.py3-none-win_amd64.whl (17.8 MB)
# Collecting plotly
#   Using cached plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
# Requirement already satisfied: pyparsing in d:\pythonproject\lib\site-packages (from ConfigSpace<=0.4.10->autogluon) (3.0.7)
# Collecting typing
#   Using cached typing-3.7.4.3.tar.gz (78 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cffi>=1.12 in d:\pythonproject\lib\site-packages (from cryptography>=2.8->autogluon) (1.15.0)
# Collecting cloudpickle>=1.1.1
#   Using cached cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting fsspec>=0.6.0
#   Using cached fsspec-2022.1.0-py3-none-any.whl (133 kB)
# Collecting partd>=0.3.10
#   Using cached partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting pyyaml>=5.3.1
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Collecting toolz>=0.8.2
#   Using cached toolz-0.11.2-py3-none-any.whl (55 kB)
# Requirement already satisfied: click>=6.6 in d:\pythonproject\lib\site-packages (from distributed>=2.6.0->autogluon) (8.0.3)
# Collecting msgpack>=0.6.0
#   Using cached msgpack-1.0.3-cp39-cp39-win_amd64.whl (69 kB)
# Requirement already satisfied: jinja2 in d:\pythonproject\lib\site-packages (from distributed>=2.6.0->autogluon) (3.0.3)
# Collecting tblib>=1.6.0
#   Using cached tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting zict>=0.1.3
#   Using cached zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: setuptools in d:\pythonproject\lib\site-packages (from distributed>=2.6.0->autogluon) (60.5.0)
# Collecting portalocker
#   Using cached portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting wheel
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting bcrypt>=3.1.3
#   Using cached bcrypt-3.2.0-cp36-abi3-win_amd64.whl (28 kB)
# Collecting pynacl>=1.0.1
#   Using cached PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
# Requirement already satisfied: joblib>=0.11 in d:\pythonproject\lib\site-packages (from scikit-learn<0.24,>=0.22.0->autogluon) (1.1.0)
# Requirement already satisfied: colorama in d:\pythonproject\lib\site-packages (from tqdm>=4.38.0->autogluon) (0.4.4)
# Collecting contextvars
#   Using cached contextvars-2.4.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting protobuf
#   Using cached protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Collecting tokenizers>=0.9.4
#   Using cached tokenizers-0.11.4-cp39-cp39-win_amd64.whl (3.3 MB)
# Collecting sacremoses>=0.0.38
#   Using cached sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
# Collecting sentencepiece==0.1.95
#   Using cached sentencepiece-0.1.95-cp39-cp39-win_amd64.whl (1.2 MB)
# Collecting flake8
#   Using cached flake8-4.0.1-py2.py3-none-any.whl (64 kB)
# Collecting regex
#   Using cached regex-2022.1.18-cp39-cp39-win_amd64.whl (273 kB)
# Collecting sacrebleu
#   Using cached sacrebleu-2.0.0-py3-none-any.whl (90 kB)
# Collecting yacs>=0.1.6
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.25.0,>=1.24.0
#   Downloading botocore-1.24.0-py3-none-any.whl (8.5 MB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.1-py3-none-any.whl (79 kB)
# Requirement already satisfied: fonttools>=4.22.0 in d:\pythonproject\lib\site-packages (from matplotlib->autogluon) (4.29.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\pythonproject\lib\site-packages (from matplotlib->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\pythonproject\lib\site-packages (from matplotlib->autogluon) (0.11.0)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting minio
#   Downloading minio-7.1.3-py3-none-any.whl (75 kB)
# Requirement already satisfied: tomli>=1.0.0 in d:\pythonproject\lib\site-packages (from pytest->autogluon) (2.0.0)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: attrs>=19.2.0 in d:\pythonproject\lib\site-packages (from pytest->autogluon) (21.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\pythonproject\lib\site-packages (from requests->autogluon) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\pythonproject\lib\site-packages (from requests->autogluon) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\pythonproject\lib\site-packages (from requests->autogluon) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\pythonproject\lib\site-packages (from requests->autogluon) (3.3)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pycparser in d:\pythonproject\lib\site-packages (from cffi>=1.12->cryptography>=2.8->autogluon) (2.21)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.0-cp39-cp39-win_amd64.whl (23.2 MB)
# Collecting numpy
#   Downloading numpy-1.21.5-cp39-cp39-win_amd64.whl (14.0 MB)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp39-cp39-win_amd64.whl (58 kB)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\pythonproject\lib\site-packages (from jinja2->distributed>=2.6.0->autogluon) (2.0.1)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: pywin32>=226 in d:\pythonproject\lib\site-packages (from portalocker->gluoncv<0.9.0,>=0.5.0->autogluon) (303)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Using legacy 'setup.py install' for fastparquet, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for ConfigSpace, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for Pillow, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for psutil, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for scikit-learn, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for openml, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for liac-arff, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for thrift, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for contextvars, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for typing, since package 'wheel' is not installed.
# Building wheels for collected packages: pyarrow
#   Building wheel for pyarrow (pyproject.toml): started
#   Building wheel for pyarrow (pyproject.toml): finished with status 'error'
# Failed to build pyarrow
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\PythonProject\lib\site-packages\pandas\compat\_optional.py:126, in import_optional_dependency(name, extra, errors, min_version)
#     125 try:
# --> 126     module = importlib.import_module(name)
#     127 except ImportError:
#
# File C:\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [1], in <module>
#       3 import pandas as pd
#       4 import numpy as np
# ----> 6 data = pd.read_feather('house_sales.ftr')
#
# File D:\PythonProject\lib\site-packages\pandas\io\feather_format.py:125, in read_feather(path, columns, use_threads, storage_options)
#      96 @doc(storage_options=_shared_docs["storage_options"])
#      97 def read_feather(
#      98     path: FilePath | ReadBuffer[bytes],
#    (...)
#     101     storage_options: StorageOptions = None,
#     102 ):
#     103     """
#     104     Load a feather-format object from the file path.
#     105
#    (...)
#     123     type of object stored in file
#     124     """
# --> 125     import_optional_dependency("pyarrow")
#     126     from pyarrow import feather
#     128     with get_handle(
#     129         path, "rb", storage_options=storage_options, is_text=False
#     130     ) as handles:
#
# File D:\PythonProject\lib\site-packages\pandas\compat\_optional.py:129, in import_optional_dependency(name, extra, errors, min_version)
#     127 except ImportError:
#     128     if errors == "raise":
# --> 129         raise ImportError(msg)
#     130     else:
#     131         return None
#
# ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.

# %%
import scipy
import numpy as np
scipy.__version__, np.__version__

# %% [markdown]
# We select a few common columns to make our training fast. You need to select more columns to make your model more accurate.

# %%
df = data[['Sold Price', 'Sold On', 'Type', 'Year built', 'Bedrooms', 'Bathrooms']].copy()
# uncomment the below line to save memory
# del data

# %% [markdown]
# We copy the code from EDA to convert `Sold Price` to numerical values, which is our prediction target. We also remove examples whose prices are too high or too low.

# %%
c = 'Sold Price'
if c in df.select_dtypes('object').columns:
    df.loc[:,c] = np.log10(
            pd.to_numeric(df[c].replace(r'[$,-]', '', regex=True)) + 1)
df = df[(df['Sold Price'] >= 4 ) & (df['Sold Price'] <= 8 )]

# %% [markdown]
# We use the house sales between 2021-2-15 and 2021-3-1 as our test data. You can use any example before 2021-2-15, but not after. In other words, we pretend we are launching our model on 2021-2-15 and testing it for 2 weeks. Here we only use sales in 2021 for fast training, but you can use more to improve accuracy.

# %%
test_start, test_end = pd.Timestamp(2021, 2, 15), pd.Timestamp(2021, 3, 1)
train_start = pd.Timestamp(2021, 1, 1)
df['Sold On'] = pd.to_datetime(df['Sold On'], errors='coerce')
train = df[(df['Sold On'] >= train_start) & (df['Sold On'] < test_start)]
test = df[(df['Sold On'] >= test_start) & (df['Sold On'] < test_end)]
train.shape, test.shape

# %% [markdown]
# Define our evaluation metric.

# %%
def rmsle(y_hat, y):
    # we already used log prices before, so we only need to compute RMSE
    return sum((y_hat - y)**2 / len(y))**0.5

# %% [markdown]
# ## AutoGluon Baseline
#
# We provide a baseline model trained by AutoGluon (AG). AG is an automl tool that performs automatic feature engineering, model selections, and ensemble. You are welcome to use any model and tool in achieving the best results possible in your homework. However, we recommend that you reuse the following training code so that you can focus on data preprocessing.

# %%
from autogluon.tabular import TabularPredictor
    
label = 'Sold Price'    
predictor = TabularPredictor(label=label).fit(train)

# %% [markdown]
# Test the performance of each model.

# %%
predictor.leaderboard(test, silent=True)

# %% [markdown]
# Next, we compute the importance of each feature, along with several other metrics. It loooks like the `Sold On` feature is not very useful, likely because the houses in the test data were all sold late. You can choose to either remove such a feature, or find a way to extract a more useful presentation from it.

# %%
predictor.feature_importance(test)

# %% [markdown]
# Finally, let's predict and evaluate the RMSLE.

# %%
preds = predictor.predict(test.drop(columns=[label]))
rmsle(preds, test[label])

# %% [markdown]
# ## Your Solution
#
# Please include your solution in the following section. (You are welcome to edit and delete code in previous sections).
#
# Your goal is to train a model using the features in the original dataset that minimizes the RMSLE on the validation dataset. While the naïve model achieves an RMSLE of ~0.3, it is possible to achieve an RMSLE of less than 0.08 on the same dataset.
#
# Here is a list of ideas you could explore:
#
# - More features: We only selected a small set of columns to use in training. You can add more, especially the ones we examined in EDA.
# - Data type conversion: Most data columns are strings; you may need to convert them into numerical values.
# - Data cleaning: There are NAN and outliers sprinkled throughout the dataset. You should find ways to selectively filter and remove them.
# - More examples: We only included sales made in 2021; there is a large number of examples in previous years that you can also include.

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# FIN
